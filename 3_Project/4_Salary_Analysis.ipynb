# %%
import ast
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt
import seaborn as sns

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %% [markdown]
# ## How well do jobs and skills pay for data analysts?

# %% [markdown]
# ### 1. How well do data jobs pay?
#
# ### Methodology
# - Evaluate median salary for top 6 data jobs
# - Find the median salary per skill for Data Analysts
# - Visualize for highest paying skills and most demanded skills

# %%
df_US = df[df['job_country'] == 'United States'].dropna(subset='salary_year_avg')
df_US
# Out:
#        job_title_short                                          job_title  \
# 92       Data Engineer            Remote - Data Engineer - Permanent - W2
# 100     Data Scientist            Data Scientist, Risk Data Mining - USDS
# 109       Data Analyst              Senior Supply Chain Analytics Analyst
# 116     Data Scientist                                     Data Scientist
# 146      Data Engineer  Data Engineer Graduate (Real Time Communicatio...
# ...                ...                                                ...
# 785563  Data Scientist  Data Scientist I/II (Model Risk Management & M...
# 785624   Data Engineer                   Data Analytics Engineer (Hybrid)
# 785641   Data Engineer                                      Data Engineer
# 785648  Data Scientist  Director Data Scientist - Commercial Platforms...
# 785692  Data Scientist               Data Scientist- Hybrid Work Location
#
#              job_location                                    job_via  \
# ...

# %%
job_titles = df_US['job_title_short'].value_counts().sort_values(ascending=False).head(6).index.to_list()
job_titles
# finding the top 6 roles and converting this to a list
# Out:
# ['Data Scientist',
#  'Data Analyst',
#  'Data Engineer',
#  'Senior Data Scientist',
#  'Senior Data Engineer',
#  'Senior Data Analyst']

# %%
df_US_top6 = df_US[df_US['job_title_short'].isin (job_titles)]
df_US_top6
# Out:
#        job_title_short                                          job_title  \
# 92       Data Engineer            Remote - Data Engineer - Permanent - W2
# 100     Data Scientist            Data Scientist, Risk Data Mining - USDS
# 109       Data Analyst              Senior Supply Chain Analytics Analyst
# 116     Data Scientist                                     Data Scientist
# 146      Data Engineer  Data Engineer Graduate (Real Time Communicatio...
# ...                ...                                                ...
# 785563  Data Scientist  Data Scientist I/II (Model Risk Management & M...
# 785624   Data Engineer                   Data Analytics Engineer (Hybrid)
# 785641   Data Engineer                                      Data Engineer
# 785648  Data Scientist  Director Data Scientist - Commercial Platforms...
# 785692  Data Scientist               Data Scientist- Hybrid Work Location
#
#              job_location                                    job_via  \
# ...

# %%
job_order = df_US_top6.groupby('job_title_short')['salary_year_avg'].median().sort_values(ascending=False).index
job_order
# this determine the order for which we can plot from highest to lowest median salary in the boxplot
# Out:
# Index(['Senior Data Scientist', 'Senior Data Engineer', 'Data Scientist',
#        'Data Engineer', 'Senior Data Analyst', 'Data Analyst'],
#       dtype='object', name='job_title_short')

# %% [markdown]
# ### Plotting the data

# %%
plt.figure(figsize=(10, 7))

sns.boxplot(data=df_US_top6, x='salary_year_avg', y='job_title_short', order=job_order)

plt.title('Salary Distributions in the United States', fontsize=16, y=1.03)
plt.xlabel('Yearly Salary ($USD)')
plt.ylabel('')
plt.xlim(0, 600000)

ax_att = plt.gca()
ax_att.xaxis.set_major_formatter(plt.FuncFormatter(lambda x, pos: f'${int(x/1000)}K'))
plt.show()

# %% [markdown]
# ###  2. How well do skills pay for data analysts?

# %%
df_DA_US = df[(df['job_title_short'] == 'Data Analyst') & (df['job_country'] == 'United States')].copy()
df_DA_US.head()
# Out:
#    job_title_short                                     job_title  \
# 36    Data Analyst                                  Data Analyst
# 68    Data Analyst                     Sr. Research Data Analyst
# 73    Data Analyst   Entry level / Systems Data Analyst (Remote)
# 79    Data Analyst                    Data Analyst/Report Writer
# 93    Data Analyst  IT Finance / TBM Data Analyst - Remote | WFH
#
#       job_location               job_via job_schedule_type  \
# 36  Des Moines, IA       via Trabajo.org         Full-time
# 68   Baltimore, MD      via ZipRecruiter         Full-time
# 73        Anywhere          via LinkedIn        Contractor
# 79      Austin, TX  via Jobs Trabajo.org         Full-time
# 93        Anywhere          via LinkedIn         Full-time
#
#     job_work_from_home          search_location     job_posted_date  \
# 36               False  Illinois, United States 2023-11-06 13:01:22
# 68               False  New York, United States 2023-03-24 13:01:00
# ...

# %%
df_DA_US = df_DA_US.dropna(subset='salary_year_avg')
df_DA_US.head()
# Out:
#      job_title_short                                    job_title  \
# 109     Data Analyst        Senior Supply Chain Analytics Analyst
# 180     Data Analyst                             Data Analyst III
# 410     Data Analyst  IT Business Lead Data Analyst - VP - Hybrid
# 988     Data Analyst                        DATA ANALYST (ONSITE)
# 1413    Data Analyst                          Junior BI Developer
#
#             job_location                job_via job_schedule_type  \
# 109             Anywhere             via Get.It         Full-time
# 180        Dos Palos, CA  via My ArkLaMiss Jobs         Full-time
# 410   Atlantic Beach, FL   via ComputerJobs.com         Full-time
# 988      Springfield, MA             via Indeed         Full-time
# 1413         Atlanta, GA        via Ai-Jobs.net         Full-time
#
#       job_work_from_home            search_location     job_posted_date  \
# 109                 True    Illinois, United States 2023-10-12 13:02:19
# ...

# %%
df_DA_US = df_DA_US.explode('job_skills')

df_skills = df_DA_US.groupby('job_skills')['salary_year_avg'].agg(['count', 'median'])
df_skills
# Out:
#             count     median
# job_skills
# airflow        44  116250.00
# airtable        5   90000.00
# alteryx       106  106281.25
# angular         8  107500.00
# ansible         1  159640.00
# ...           ...        ...
# wire            4   74250.00
# word          461   81194.75
# workfront       3   75000.00
# wrike           1   75000.00
# zoom           15   80740.00
#
# [170 rows x 2 columns]

# %%
df_skills_pay = df_skills.sort_values(by='median', ascending=False).head(10)
df_skills_pay
# Out:
#               count    median
# job_skills
# dplyr             2  196250.0
# bitbucket         3  189000.0
# gitlab            3  186000.0
# solidity          1  179000.0
# hugging face      1  175000.0
# couchbase         1  160515.0
# ansible           1  159640.0
# mxnet             2  149000.0
# cassandra         6  148250.0
# vmware            1  147500.0

# %% [markdown]
# ### Plotting the data

# %%
plt.figure(figsize=(8, 6))

sns.barplot(data=df_skills_pay, x='median', y='job_skills', hue='median', palette='dark:b_r', width=0.73) 
sns.set_theme(style='ticks')
sns.despine()
 
plt.title('Top 10 Highest Paid Skills for Data Analysts in the US', fontsize=14, y=1.02)
plt.xlabel('Median Salary')
plt.ylabel('')
plt.legend().set_visible(False)

ax= plt.gca()
ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda x, pos: f'${int(x/1000)}K'))

# %% [markdown]
# Note: although these are the skills that offer the highest median salary, when we look at the count for each of these associated skills, they are very low (<10). Therefore, these skills are in fact not common amongst data analyst job postings in the US, implying that they are required for very niche job sectors that are willing to pay a premium for this skillset.
